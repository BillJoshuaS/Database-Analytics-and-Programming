# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("County.csv")

# Define a mapping dictionary for state codes to full names
state_mapping = {
    'AK': 'Alaska', 'AL': 'Alabama', 'AR': 'Arkansas', 'AZ': 'Arizona', 'CA': 'California', 'CO': 'Colorado',
    'CT': 'Connecticut', 'DC': 'District of Columbia', 'DE': 'Delaware', 'FL': 'Florida', 'GA': 'Georgia',
    'HI': 'Hawaii', 'IA': 'Iowa', 'ID': 'Idaho', 'IL': 'Illinois', 'IN': 'Indiana', 'KS': 'Kansas', 'KY': 'Kentucky',
    'LA': 'Louisiana', 'MA': 'Massachusetts', 'MD': 'Maryland', 'ME': 'Maine', 'MI': 'Michigan', 'MN': 'Minnesota',
    'MO': 'Missouri', 'MS': 'Mississippi', 'MT': 'Montana', 'NC': 'North Carolina', 'ND': 'North Dakota',
    'NE': 'Nebraska', 'NH': 'New Hampshire', 'NJ': 'New Jersey', 'NM': 'New Mexico', 'NV': 'Nevada',
    'NY': 'New York', 'OH': 'Ohio', 'OK': 'Oklahoma', 'OR': 'Oregon', 'PA': 'Pennsylvania', 'RI': 'Rhode Island',
    'SC': 'South Carolina', 'SD': 'South Dakota', 'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah', 'VA': 'Virginia',
    'VT': 'Vermont', 'WA': 'Washington', 'WI': 'Wisconsin', 'WV': 'West Virginia', 'WY': 'Wyoming'
}

# Replace state codes with full names
df['LSTATE'] = df['LSTATE'].map(state_mapping)

df['AQI%Good'] = df['AQI%Good'].str.rstrip('%').astype(float)

# Grouping by state and calculating the mean AQI%Good for each state
mean_aqi_by_state = df.groupby('LSTATE')['AQI%Good'].mean().reset_index()

# Set the seaborn style
sns.set_style("whitegrid")

# Plotting the bar plot with seaborn
plt.figure(figsize=(12, 14))  # Adjust figure size accordingly
ax = sns.barplot(x='AQI%Good', y='LSTATE', data=mean_aqi_by_state, hue='LSTATE', palette='plasma', dodge=False)
plt.title('Mean Air Quality Index % in each State', fontsize=16)
plt.xlabel('Mean AQI%Good', fontsize=16)
plt.ylabel('State', fontsize=16)
plt.xticks(fontsize=10, fontweight='bold')  # Modify x ticks font size and style
plt.yticks(fontsize=12, fontweight='bold')  # Modify y ticks font size and style
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("County.csv")
state_mapping = {
    'AK': 'Alaska', 'AL': 'Alabama', 'AR': 'Arkansas', 'AZ': 'Arizona', 'CA': 'California', 'CO': 'Colorado',
    'CT': 'Connecticut', 'DC': 'District of Columbia', 'DE': 'Delaware', 'FL': 'Florida', 'GA': 'Georgia',
    'HI': 'Hawaii', 'IA': 'Iowa', 'ID': 'Idaho', 'IL': 'Illinois', 'IN': 'Indiana', 'KS': 'Kansas', 'KY': 'Kentucky',
    'LA': 'Louisiana', 'MA': 'Massachusetts', 'MD': 'Maryland', 'ME': 'Maine', 'MI': 'Michigan', 'MN': 'Minnesota',
    'MO': 'Missouri', 'MS': 'Mississippi', 'MT': 'Montana', 'NC': 'North Carolina', 'ND': 'North Dakota',
    'NE': 'Nebraska', 'NH': 'New Hampshire', 'NJ': 'New Jersey', 'NM': 'New Mexico', 'NV': 'Nevada',
    'NY': 'New York', 'OH': 'Ohio', 'OK': 'Oklahoma', 'OR': 'Oregon', 'PA': 'Pennsylvania', 'RI': 'Rhode Island',
    'SC': 'South Carolina', 'SD': 'South Dakota', 'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah', 'VA': 'Virginia',
    'VT': 'Vermont', 'WA': 'Washington', 'WI': 'Wisconsin', 'WV': 'West Virginia', 'WY': 'Wyoming'
}

# Replace state codes with full names
df['LSTATE'] = df['LSTATE'].map(state_mapping)


# Grouping by state and calculating the mean WaterQualityVPV for each state
mean_aqi_by_state = df.groupby('LSTATE')['WaterQualityVPV'].mean().reset_index()

# Set the seaborn style
sns.set_style("whitegrid")

# Plotting the line plot with seaborn
plt.figure(figsize=(14, 6))
ax = sns.lineplot(x='LSTATE', y='WaterQualityVPV', data=mean_aqi_by_state, marker='o', color='red', linewidth=2.5)
plt.title('Mean Water Quality VPV in each State', fontsize=16)
plt.xlabel('State', fontsize=16)
plt.ylabel('Mean WaterQualityVPV', fontsize=16)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding grid lines for better readability
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Adding horizontal line at y=0 for reference
plt.axhline(y=0, color='blue', linewidth=2, linestyle='--')

# Adding text annotation for the maximum value
max_value = mean_aqi_by_state['WaterQualityVPV'].max()
max_state = mean_aqi_by_state.loc[mean_aqi_by_state['WaterQualityVPV'].idxmax(), 'LSTATE']
plt.text(mean_aqi_by_state['LSTATE'].max(), max_value, f'Max: {max_value:.2f} ({max_state})', fontsize=12, ha='right')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("cost_of_living_us (1).csv")

state_mapping = {
    'AK': 'Alaska', 'AL': 'Alabama', 'AR': 'Arkansas', 'AZ': 'Arizona', 'CA': 'California', 'CO': 'Colorado',
    'CT': 'Connecticut', 'DC': 'District of Columbia', 'DE': 'Delaware', 'FL': 'Florida', 'GA': 'Georgia',
    'HI': 'Hawaii', 'IA': 'Iowa', 'ID': 'Idaho', 'IL': 'Illinois', 'IN': 'Indiana', 'KS': 'Kansas', 'KY': 'Kentucky',
    'LA': 'Louisiana', 'MA': 'Massachusetts', 'MD': 'Maryland', 'ME': 'Maine', 'MI': 'Michigan', 'MN': 'Minnesota',
    'MO': 'Missouri', 'MS': 'Mississippi', 'MT': 'Montana', 'NC': 'North Carolina', 'ND': 'North Dakota',
    'NE': 'Nebraska', 'NH': 'New Hampshire', 'NJ': 'New Jersey', 'NM': 'New Mexico', 'NV': 'Nevada',
    'NY': 'New York', 'OH': 'Ohio', 'OK': 'Oklahoma', 'OR': 'Oregon', 'PA': 'Pennsylvania', 'RI': 'Rhode Island',
    'SC': 'South Carolina', 'SD': 'South Dakota', 'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah', 'VA': 'Virginia',
    'VT': 'Vermont', 'WA': 'Washington', 'WI': 'Wisconsin', 'WV': 'West Virginia', 'WY': 'Wyoming'
}

# Replace state codes with full names
df['state'] = df['state'].map(state_mapping)

# Group by state and calculate the sum of total income and total cost
df_state_totals = df.groupby('state')[['median_family_income', 'total_cost']].sum().reset_index()

# Plotting with seaborn lineplot
plt.figure(figsize=(14, 8))

# Set the seaborn style to 'ticks'
sns.set_style("dark")

sns.lineplot(data=df_state_totals, x='state', y='median_family_income', label='Total Income', marker='o')
sns.lineplot(data=df_state_totals, x='state', y='total_cost', label='Total Cost', marker='o')

# Adding labels and title
plt.title('Total Income and Total Cost by State', fontsize=16, fontweight='bold', fontfamily='sans-serif')
plt.xlabel('State', fontsize=14, fontweight='bold', fontfamily='sans-serif')
plt.ylabel('Amount ($)', fontsize=14, fontweight='bold', fontfamily='sans-serif')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("County.csv")

# Define a mapping dictionary for state codes to full names
state_mapping = {
    'AK': 'Alaska', 'AL': 'Alabama', 'AR': 'Arkansas', 'AZ': 'Arizona', 'CA': 'California', 'CO': 'Colorado',
    'CT': 'Connecticut', 'DC': 'District of Columbia', 'DE': 'Delaware', 'FL': 'Florida', 'GA': 'Georgia',
    'HI': 'Hawaii', 'IA': 'Iowa', 'ID': 'Idaho', 'IL': 'Illinois', 'IN': 'Indiana', 'KS': 'Kansas', 'KY': 'Kentucky',
    'LA': 'Louisiana', 'MA': 'Massachusetts', 'MD': 'Maryland', 'ME': 'Maine', 'MI': 'Michigan', 'MN': 'Minnesota',
    'MO': 'Missouri', 'MS': 'Mississippi', 'MT': 'Montana', 'NC': 'North Carolina', 'ND': 'North Dakota',
    'NE': 'Nebraska', 'NH': 'New Hampshire', 'NJ': 'New Jersey', 'NM': 'New Mexico', 'NV': 'Nevada',
    'NY': 'New York', 'OH': 'Ohio', 'OK': 'Oklahoma', 'OR': 'Oregon', 'PA': 'Pennsylvania', 'RI': 'Rhode Island',
    'SC': 'South Carolina', 'SD': 'South Dakota', 'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah', 'VA': 'Virginia',
    'VT': 'Vermont', 'WA': 'Washington', 'WI': 'Wisconsin', 'WV': 'West Virginia', 'WY': 'Wyoming'
}

# Replace state codes with full names
df['LSTATE'] = df['LSTATE'].map(state_mapping)

#df['AQI%Good'] = df['AQI%Good'].str.rstrip('%').astype(float)
df['2022 Population'] = df['2022 Population'].str.replace(',', '').astype(float)

# Grouping by state and calculating the mean AQI%Good for each state
mean_aqi_by_state = df.groupby('LSTATE')['2022 Population'].mean().reset_index()

# Set the seaborn style
sns.set_style("whitegrid")

# Plotting the bar plot with seaborn
plt.figure(figsize=(12, 13))  # Adjust figure size accordingly
ax = sns.barplot(x='2022 Population', y='LSTATE', data=mean_aqi_by_state, hue='LSTATE', palette='icefire', dodge=False)
plt.title('Mean Population for the year 2022 in each State for all counties', fontsize=16)
plt.xlabel('2022 Population', fontsize=16)
plt.ylabel('State', fontsize=16)
plt.xticks(fontsize=10, fontweight='bold')  # Modify x ticks font size and style
plt.yticks(fontsize=12, fontweight='bold')  # Modify y ticks font size and style
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
